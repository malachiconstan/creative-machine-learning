# %%
import os
import glob
import tensorflow as tf
import tensorflow.keras as keras

from PIL import Image
from utils.preprocessing import random_image_sample, get_image_dataset

import matplotlib.pyplot as plt

# %%
data_directory = os.path.join(os.getcwd(),'data')
image_paths = glob.glob(os.path.join(data_directory,'gallery_pavilion','*.jpeg'))

# %%
# %load_ext autoreload
# %autoreload 2

# %%
random_image_sample(image_paths)

# %%
BATCH_SIZE = 32
IMG_HEIGHT = 180
IMG_WIDTH = 180

# %%
train_dataset = get_image_dataset(os.path.join(data_directory,'gallery_pavilion','*.jpeg'), BATCH_SIZE)

# %%
image_batch, _ = next(iter(train_ds))

plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image_batch[i].numpy().astype("uint8"))
    plt.axis("off")
